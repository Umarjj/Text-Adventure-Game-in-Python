# %% [markdown]
# # Cast Away -  Text Adventure Game
#
# ## Save the sole surviver of a crashed plan
#
# Purpose of the this game to save the life of a sole surviver of a crashed plan and help him to reach home safely with his family.
#
# Stage 1. Survive in occasion by taking the right equipment
# Stage 2. Survive on island by arranging the food and shelter
# Stage 3. Prepare to escape the island by taking right equipment
#
# Our map can be visualized as follows:
#
#
#     Occasion --> Island --> Escape (win)
#               |          |
#               `----------`------> fail
#
# '

# %%
# import colorama
from colorama import Fore, Style  

#Start of the Game
def start():
    """
DocString:

    Introduction:
    This game is a text adventure game based on a movie named Castaway, where Obsessively punctual FedEx executive Chuck Noland is en route to an assignment in Malaysia when his plane crashes over the Pacific Ocean during a storm. As the sole survivor of the flight, he survives in this condition returns to civilization and reunites with his loved ones.  
    
    Purpose:
    The sole survivor of the flight should take the right decision to reach a safe place and survive to plan for an escape to reach back to his family.
    
    Reference: Move - "Cast Away" (2000)
    Known Bugs and/or Errors:
    None.    
    
    Author: Umar Farooq (MBAN I)
    
    Date: 01.27.2022
        
    """
    print("""

    ##################################################

    Cast Away -  A sole survivor of a crashed plan  

    ##################################################
    
    
    """)    
    Name=input(prompt="Enter you name to start the game:").capitalize()
    
    print(f"Wencome! {Name}")
    
    #Description of the game which is based on a movie
    print("""This game is based on a movie named Castaway, where Obsessively punctual FedEx executive Chuck Noland is en route to an assignment in Malaysia when his plane crashes over the Pacific Ocean during a storm.""") 
 
    
    print("🛩", "🛩", "✈", "🛩", "🛬")
   
    print("""
    🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
    🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
    🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
    🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
    """)
    
    print("""As a sole survivor of the flight, you need to survive in this condition and return to civilization and reunite with your loved ones.  .\n""")
    scene_1()
    
#start of scene 1

def scene_1():

    #Creating a dictionary for selecting dynamic options
    dic= {"1":"Life Raft", "2":"Small Boat", "3": "Oxygen Cylinder Kit"}
    
    #using for loop to display the options
    for key, value in dic.items():
        print(key + ". "+ str(value ))
        
    #input from user to select the equipment for survival
    action_1= input(prompt= """\n Q1: what equipent you prefer to survive in rough occean?
    Hint: choose the options 1,2,3 """).casefold()
  
   
    #add conditions to handle multiple inputs from user
    if "2" in action_1 or "small" in action_1 or "boat" in action_1 or "two" in action_1:
        print("_____________")
        print(Fore.RED + "Warning: You have chosen small boat that wouldn’t be survive in a sea strom with small boat. \n ")
        print("Please Try again!")
        scene_1()
        
    elif "3" in action_1 or "oxygen" in action_1 or "cylinder" in action_1 or "kit"in action_1 or "three"in action_1:
        print("_____________")
        print(Fore.RED + "Warning: Oxygen Cylinder will not help to survive for a long time in sea \n")
        print("Please Try again!")
        scene_1()
        
    elif "1"in action_1 or "life" in action_1 or "raft" in action_1 or "one"in action_1:
        print("You choose the right item, Life Raft will help you to survive in storm. \n\n\n")
        scene_2()
    else:
        print("Invalid Entry. Kindly choose the item within the list.\n")
        print("Please Try again!")
        scene_1()
     # end of if condition


#start of 2nd scene
def scene_2():
    
    print(Fore.BLUE + """You are successfuly arrived to an island.
    
Now, you are alone on a deserted island with nothing but a few FedEx packages that have washed up on shore.\n\n""")
    print("🗻🗻🗻🗻🗻🗻🗻🗻")
    #inputs from user to see the decision that will he survive or escape
    action_2= input(prompt = """What would be your preferences to stay alive. Hint: Enter options 1,2,3 \n
    1. Survive on island and wait for help 
    2. Escape from island
    3. Both survive and escape 
    
    """).casefold()
    
    #add conditions to handle different types of inputs from user
    if "1" in action_2 or "survive" in action_2 or "help" in action_2 or "one"  in action_2:
        scene_3()
    elif "2" in action_2 or "escape" in action_2 or "island" in action_2 or "two"  in action_2:
        print("Immediate escape would not be possible. First you have to prepare yourself to survive and then plan for escape")
        question= input(prompt= "Do you want to prepare for survive first? Hint: Enter Yes/No").casefold()
        if "yes" in question or "y" in question:
            scene_3()
        else:
            print(Fore.RED + "Unfortunately you can not escape without surviving for a short term.")
            fail()
    elif "3" in action_2 or "both" in action_2 or "survive and escape" in action_2 or "three"  in action_2:
        scene_3()
    else:
        print("Invalid entry, Please enter the right option.")  

#start of scene 3
def scene_3():
    
    score=0
    #A score variable that will increase the score if you answer correctly for the survival questions.
    print("""It would not be a easy to survive on a deserted island without proper food and shelter.
          So, in order to survive, you should arrange the food, shelter and maintain good health. \n""")
    try: #handling errors that user can only input from given options 
        #Input from user about something to eat on the island.
        action_3=input(prompt="""Q1. What will you eat on this island?
        Hint: Enter options 1,2,3,4 
        1.Goat
        2.Bird
        3.Sand
        4.Fish

        \n""").casefold()

        #if conditions to handle the user input
        if action_3=="1" or action_3=="goat" or action_3=="one" :
            print("Sorry, it's not possible to find goats in Island.")

        elif action_3=="2" or action_3=="bird" or action_3=="two":
            print("Sorry, you are not enough skillful to catch birds in Island.")

        elif action_3=="3" or action_3=="sand" or action_3=="three":   
            print("Sorry, how can you eat sand to survive.")

        elif action_3=="4" or action_3=="fish" or action_3=="four":
            print("That's the right option, there are a lot of fish available in water near island.")
            score= score+1
        else:
            print("Invalid entry.")

        # input from the user about the information regarding healthy water
        action_4=input(prompt="""Q2. What you will drink?
        Hint: Enter options 1,2,3,4
        1. Sea water
        2. Coconut Water
        3. RainWater
        4. Wine

        \n""").casefold()

        # if condition to handle the user input
        if action_4=="1" or action_4=="sea" or action_4=="one":
            print("Sorry, Sea water is not drinkable.")

        elif action_4=="2" or action_4=="coconut" or action_4=="two":
            print("Yes that's the right choice, Coconut water is drinkable.")
            score= score+1
        elif action_4=="3" or action_4=="rain" or action_4=="three":   
            print("Yes that's the right choice, Rain water is drinkable.")
            score= score+1
        elif action_4=="4" or action_4=="wine" or action_4=="four":
            print("Sorry, Wine is not available in island")
        else:
            print("Invalid entry.")

        # input from about the shelter in the island      
        action_5=input(prompt="""Q3. where will you stay?
        Hint: Enter options 1,2,3,4
        1. Inside the water
        2. Cave
        3. On beach at sand
        4. On Trees

        \n""").casefold()
        # input handling using if conditions
        if "1" in action_5 or "3" in action_5 or "4" in action_5:
            print("Sorry, This is not the right options to stay.")
        elif "inside water" in action_5 or  "beach" in action_5 or "sand" in action_5 or "trees" in action_5:
            print("Sorry, This is not the right options to stay.")
        elif "one" in action_5 or "three"  in action_5 or "five"  in action_5:
            print("Sorry, This is not the right options to stay.")

        elif "2" in action_5 or "cave" in action_5 or "two" in action_5: 
            print("That's the right choice to stay.")
            score= score+1
        else:
            print("Invalid entry.")    
        # input from the user to know how will he treat his diseases while living in island
        action_6=input(prompt="""Q4. How to protect yourself against diseases? 
        Hint: Enter options 1,2,3,4
        1. Take Medicine 
        2. Use Herbal Treatments
        3. Home Remedies
        4. Try to Escape before getting worse

        \n""").casefold()
        # handling the user inputs using if conditions    
        if "2" in action_6 or "3" in action_6 or "two" in action_6 or "three" in action_6 or "home" in action_6 or "herbal treatments" in action_6:
            print("That would be a good option but would be difficult to survive in a long run.")

        elif "1" in action_6 or "medicine" in action_6 or "one" in action_6: 
             print("How would you get the medicine in the island?")

        elif "4"in action_6 or "four"in action_6 or "try to escape"in action_6: 
            print("Yes, That's the right option for better long term survival")
            score= score+1
        else:
            print("Invalid entry.")    
        # scoring the correct answers and deciding if he could survive on the island or not
        if score>=2:
            scene_4()
        else:
            print(Fore.RED + "Unfortunately, it would not be possible for you to survive, because of your weak survival skills.\n")
            fail()
    except:
        print("Please enter the wordings that are given in the options")
        print("Invalid entry")
# start of scene4 
def scene_4():
    print(Fore.GREEN + """It seems that you will be able to survive on this island for a short time, 
but it would be better if you escape as soon as possible to reunite with your loved ones.\n """)
    # input from the user if he want to escape
    Ques=input(prompt="Do you want to plan to escape? Hint: Yes/NO").casefold()
    #handeling the input using if condition
    if Ques=="yes" or Ques=="y":
        scene_6()
    elif Ques=="no" or Ques=="n":
        scene_5()
    else:
        print("Please enter Yes or No")
        scene_4()
        
#start of scene5
def scene_5():
    print(Fore.RED + "Unfortunately, it would not be possible for you to survive on this Island within your surviving efforts for long run.\n")
    fail()
    # this function will fail the condition where he answer the questions correctly but don't want to escape the island.
    
#start of scene6
def scene_6():
    print("To escape to your normal life and to reunite your loved ones you have to prepare fro escape!\n")
    #input from user about the escape information
    action_7=input(prompt="""Q1. What would be the right path to escape? 
    Hint: Enter options 1,2,3,4
    1. Call help by writing HELP on Sand  
    2. Build a Boat 🛶
    3. Swim to survive  🏊‍♂️
    4. Ride on a fish 🦈
    5. Call 911 📱
    
    \n""").casefold()
    
    # handling the input types using if and nested if conditions
    if "1"in action_7 or "3"in action_7 or "4" in action_7 or  "5" in action_7 or "ride on fish" in action_7 or "5" in action_7:
        print("Sorry, this would not be the feasible option to escape")
        fail()
    elif "one"in action_7 or "three"in action_7 or "four" in action_7 or "five" in action_7 or "call 911" in action_7 or "call help by writing" in action_7:
        print("Sorry, this would not be the feasible option to escape")
        fail()
    elif "2" in action_7 or "two" in action_7 or "build a boat" in action_7:
        # after correcting its the proceeding question
        Ques2=input(prompt="Do you know how to build a boat. Hint: Yes/No").casefold()
        # handling the nested if input
        if Ques2=="yes" or Ques2=="y":
            #further nester input regarding survival
            Ques3=input(prompt="""How you will build a boat? 🛶 Hint: Enter options 1,2,3,4
            
    1. Stone 
    2. Steel
    3. Plastic 
    4. Wood
    5. Cotton
    \n """).casefold()
            # handeling the inputs of nested question
            if "1" in Ques3 or "2"in Ques3 or "3"in Ques3 or "5"in Ques3 or "stone"in Ques3 or"steel"in Ques3:
                print("That would not be a feasible or available material to build a boat to escape.")
                fail()
            elif "one"in Ques3 or "two"in Ques3 or "three"in Ques3 or "five"in Ques3 or "plastic"in Ques3 or "cotton" in Ques3:
                print("That would not be a feasible or available material to build a boat to escape.")
                fail()
            elif "4"in Ques3 or "four"in Ques3 or "wood"in Ques3:
                 win()
            else:
                print("Please enter one of the above option")
                # end of nested if
        elif Ques=="no" or Ques=="n":
            fail()
        else:
            print("Please enter Yes or No")
            # end if 2nd nested if
    else:
        print("Please enter a valid option.")
        scene_6()
        # end of outer if condition
        
# start of the win function
def win():
    print(Fore.GREEN + """Congratulations!!!!!
    You are well prepared to survive and escape back to life""")
    print("""
    
    🚣‍♀️~'~~''~~~🚣‍♀️~'~~''~~~🚣‍ ~'~~''~~~🚣‍♀️~'~~''~~~🚣‍
     
     ``~~`~`~~```~``~``~~``~`~~``~~`~``~``~~``~`~~``~~`
     
     🏤 🌲  🌲  🌲🏡  🌲 🌲 🏘🌲
     
     
             👩‍👩‍👦
     
          
          """)
    #this function display the above statements after winning the game

#start of the fail
def fail():
    print(Fore.RED + "You've failed, but thanks for playing!")
    input(prompt = '<Press any key to exit>\n')
    # this function will exit the game and display a fail statement

start()
#end of the game
# Out:
#     ##################################################
#
#     Cast Away -  A sole survivor of a crashed plan
#
#     ##################################################
#
#
#
# Enter you name to start the game:umar
# Wencome! Umar
# This game is based on a movie named Castaway, where Obsessively punctual FedEx executive Chuck Noland is en route to an assignment in Malaysia when his plane crashes over the Pacific Ocean during a storm.
# 🛩 🛩 ✈ 🛩 🛬
#
#     🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
#     🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
#     🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
#     🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊🌊
#
# As a sole survivor of the flight, you need to survive in this condition and return to civilization and reunite with your loved ones.  .
#
# 1. Life Raft
# 2. Small Boat
# 3. Oxygen Cylinder Kit
#
#  Q1: what equipent you preper to survive in rough occean?
#     Hint: choose the options 1,2,3 1
# You choose the right item, Life Raft will help you to survive in storm.
#
#
#
# You are successfuly arrived to an island.
#
# ...
